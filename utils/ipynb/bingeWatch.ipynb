# %%
import pandas as pd
import datetime
import numpy as np

# %%
# scenario: how long will it take me to watch tsitp before my target date?
start_date = input()
end_date = input()

start_date_obj = datetime.datetime.strptime(start_date, "%d%m%Y").date()
end_date_obj = datetime.datetime.strptime(end_date, "%d%m%Y").date()

print(f"You picked {start_date_obj} to {end_date_obj} to binge watch the summer i turned pretty ")
# Out:
# You picked 2025-08-24 to 2025-08-24 to binge watch the summer i turned pretty

# %%
df = pd.read_csv("../../data/the_summer_i_turned_pretty_episodes_duration.csv")
df
# Out:
#     Season  Episode           Title  Minutes
# 0        1        1    Summer House       45
# 1        1        2    Summer Dress       39
# 2        1        3   Summer Nights       42
# 3        1        4     Summer Heat       41
# 4        1        5    Summer Catch       39
# 5        1        6    Summer Tides       44
# 6        1        7     Summer Love       45
# 7        2        1       Love Lost       50
# 8        2        2      Love Scene       44
# 9        2        3       Love Sick       46
# 10       2        4       Love Game       47
# 11       2        5       Love Fool       51
# 12       2        6       Love Fest       52
# 13       2        7     Love Affair       49
# 14       2        8   Love Triangle       54
# 15       3        1     Last Season       58
# 16       3        2  Last Christmas       56
# 17       3        3     Last Supper       54
# 18       3        4      Last Stand       57
# 19       3        5      Last Dance       66
# ...

# %%
total_minutes = df['Minutes'].sum()

from datetime import timedelta
minutes = np.int64(total_minutes)  # example value

# Use timedelta
time_duration = timedelta(minutes=int(minutes))

# Get hours and minutes
hours, remainder = divmod(time_duration.seconds, 3600)
minutes = remainder // 60

print(f"{hours} hours, {minutes} minutes")
# Out:
# 17 hours, 17 minutes
