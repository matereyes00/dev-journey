# %% [markdown]
# # Predicting Medical Costs

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Descriptive statistics
#
# The average age of a patient getting insurance is 39 years old.
#
# The average BMI of a patient is 30.6.
#
# The average number of children a patient has is 1.
#
# The average charges for a patient is 13,270.42

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## Frequency Distribution

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# pd.age.value_counts()
print(df.age.value_counts())
print(df.children.value_counts())
print(df.bmi.value_counts())
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64
# bmi
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: count, Length: 548, dtype: int64

# %%
age_counts = df['age'].value_counts().sort_index()
plt.bar(age_counts.index, age_counts.values)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
bmi_counts = df['bmi'].value_counts().sort_index()
plt.bar(bmi_counts.index, bmi_counts.values)
plt.xlabel('BMI')
plt.ylabel('Count')
plt.title('BMI Distribution')
plt.show()

# %%
children_counts = df['children'].value_counts().sort_index()
plt.bar(children_counts.index, children_counts.values)
plt.xlabel('Children')
plt.ylabel('Count')
plt.title('Number of Children Distribution')
plt.show()

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# Hypothesis: "Smokers have significantly higher medical charges than non-smokers"
#
# *Step 1*
# H<sub>0</sub>: μ<sub>smoker have high medical charges</sub> =
# H<sub>0</sub>: μ<sub>smoker have high medical charges</sub> !=

# %%
smoker_df = df[['smoker', 'charges']]
smoker_df
# Out:
#      smoker      charges
# 0       yes  16884.92400
# 1        no   1725.55230
# 2        no   4449.46200
# 3        no  21984.47061
# 4        no   3866.85520
# ...     ...          ...
# 1333     no  10600.54830
# 1334     no   2205.98080
# 1335     no   1629.83350
# 1336     no   2007.94500
# 1337    yes  29141.36030
#
# [1338 rows x 2 columns]
